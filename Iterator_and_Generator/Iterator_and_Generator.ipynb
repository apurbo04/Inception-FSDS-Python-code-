# %% [markdown]
# # Iterator

# %% [markdown]
# ## What is an Iteration
#
# Iteration is a general term for taking each item of something, one after another. Any time you use a loop, explicit or implicit, to go over a group of items, that is iteration.

# %%
num = [1,2,3]

for i in num:
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## What is Iterator
#
# An Iterator is an object that allows the programmer to traverse through a sequence of data without having to store the entire data in the memory

# %%
import sys

# %%
L = [x for x in range(1,1000000)]

# for i in L:
#   print(i*2)

print(sys.getsizeof(L))
# Out:
# 8448728

# %%
x = range(1,1000000000000000)

# for i in x:
#   print(i*2)

print(sys.getsizeof(x))
# Out:
# 48

# %% [markdown]
# ## What is Iterable
# Iterable is an object, which one can iterate over
#
#  It generates an Iterator when passed to iter() method.

# %%
L = [1,2,3]
type(L)
# L is an iterable
# Out:
# list

# %%
type(iter(L))
# iter(L) --> iterator
# Out:
# list_iterator

# %%
num = [1,2,3]

# fetch the iterator
iter_num = iter(num)


next(iter_num)
next(iter_num)
next(iter_num)
next(iter_num)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-1377947712.py in <cell line: 0>()
#       8 next(iter_num)
#       9 next(iter_num)
# ---> 10 next(iter_num)
#
# StopIteration:

# %%
num
# Out:
# [1, 2, 3]

# %%
iter_num

# %% [markdown]
# # Making our own for loop

# %%
def amr_for_loop(iterable):
  iterator = iter(iterable)

  while True:
    try:
      print(next(iterator))
    except StopIteration:
      break

# %%
a = [1,2,3]
b = range(1,11)
c = (1,2,3)
d = {1,2,3}
e = {0:1,1:1}

# %%
amr_for_loop(e)
# Out:
# 0
# 1

# %% [markdown]
# # Generator

# %%
def gen_demo():

    yield "first statement"
    yield "second statement"
    yield "third statement"

# %%
gen = gen_demo()

for i in gen:
  print(i)
# Out:
# first statement
# second statement
# third statement

# %%
gen
# Out:
# <generator object gen_demo at 0x782823c410c0>
