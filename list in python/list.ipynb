# %%
print("ok")
# Out:
# ok

# %%
L = [1,2,3]

# %%
print(id(L))
print(id(L[0]))
print(id(1))
print(id(L[1]))
print(id(2))
print(id(L[2]))
print(id(3))
# Out:
# 2670989304704
# 140727736674744
# 140727736674744
# 140727736674776
# 140727736674776
# 140727736674808
# 140727736674808

# %%
# Out:
# 140727736674744
