# %%
import logging
import os

# %%
LOG_DIR = "logs"
LOG_FILE_NAME = "application.log"

os.makedirs(LOG_DIR, exist_ok=True)

log_path = os.path.join(LOG_DIR, LOG_FILE_NAME)

logging.basicConfig(
    filename=log_path,
    format="[ %(asctime)s ] %(name)s - %(levelname)s - %(message)s",
    level=logging.INFO
)

# %%
def profile(name):
    if type(name) == str:
        print(f"Welcome {name}")
    else:
        logging.info("Your input is not valid!")

# %%
profile(1234)

# %%
def

# %%
profile(34343)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 profile(34343, 232)
#
# TypeError: profile() takes 1 positional argument but 2 were given

# %%
def devide_numbers(a,b):
    if b == 0:
        logging.info("Can't devide numbers with 0")
    else:
        return a / b

# %%
devide_numbers(3,0)

# %%
# let's read a file
try:
    with open('files/sample.txt10','r') as f:
        print(f.read())

    
except Exception as e:
    logging.info(e)
