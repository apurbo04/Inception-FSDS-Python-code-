# %% [markdown]
# # File Handling in Python
#
# ##### Types of data used for I/O:
# - Text - '12345' as a sequence of unicode chars
# - Binary - 12345 as a sequence of bytes of its binary equivalent
#
# ##### Hence there are 2 file types to deal with
# - Text files - All program files are text files
# - Binary Files - Images,music,video,exe files
#
#
#
# ### How File I/O is done in most programming languages
#
# - Open a file
# - Read/Write data
# - Close the file

# %% [markdown]
# # Writing to a file

# %%
#if the file is not present

f = open("files/sample.txt", "w")
f.write("Hello Python")
f.close()

# %%
#if the file is not present

f = open("files/sample1.txt", "w")
f.write("Hello Python")
f.close()

# %%
# f.write("Hello")

# %%
# write multiline strings
f = open('files/sample1.txt','w')
f.write('hello world')
f.write('\nhow are you?')
f.write("\nwho are you?")
f.close()

# %%
# case 2 - if the file is already present
f = open('files/sample1.txt','w')
f.write('Yo yo honey singh')
f.close()

# %%
# introducing append mode
f = open('files/sample1.txt','a')
f.write('\nI am fine')
f.close()

# %%
# write lines
L = ['hello\n','hi\n','how are you\n','I am fine']

f = open('files/sample.txt','w')
f.writelines(L)
f.close()

# %% [markdown]
# # reading from files

# %%
f = open('files/sample.txt','r')
s = f.read()
print(s)
f.close()
# Out:
# hello
# hi
# how are you
# I am fine

# %%
# reading upto n chars
f = open('files/sample.txt','r')
s = f.read(15)
print(s)
f.close()
# Out:
# hello
# hi
# how ar

# %%
# readline() -> to read line by line
f = open('files/sample.txt','r')
print(f.readline(),end='')
print(f.readline(),end='')
f.close()
# Out:
# hello
# hi

# %%
f = open('files/sample.txt','r')

while True:
    data = f.readline()

    if data == "":
        break
    else:
        print(data, end= "")


f.close()
# Out:
# hello
# hi
# how are you
# I am fine

# %% [markdown]
# # File Handling using Context Manager (With)

# %% [markdown]
# ### Using Context Manager (With)
#
# - It's a good idea to close a file after usage as it will free up the resources
# - If we dont close it, garbage collector would close it
# - with keyword closes the file as soon as the usage is over

# %%
with open("files/sample.txt", "w") as f:
    f.write("Hello there!")

# %%
# f.write("Bappy")

# %%
# read()
with open("files/sample.txt", "r") as f:
    s = f.read()
    print(s)
# Out:
# Hello there!

# %%
# readline()
with open("files/sample.txt", "r") as f:
    s = f.readline()
    print(s)
# Out:
# Hello there!

# %%
# append mode
with open("files/sample.txt", "a") as f:
    s = f.write("\nMy name is Bappy")

# %%
# moving within a file
with open("files/sample.txt", "r") as f:
    print(f.read(10))
# Out:
# Hello ther

# %%
with open("files/sample.txt", "r") as f:
    f.seek(5)
    print(f.read())
# Out:
#  there!
# My name is Bappy

# %%
with open("files/sample.txt", "r") as f:
    f.seek(5)
    print(f.tell())
# Out:
# 5

# %% [markdown]
# # Problems with working in text mode

# %% [markdown]
# - can't work with binary files like images
# - not good for other data types like int/float/list/tuples

# %%
# working with binary file
with open("files/minar.jpg", 'r') as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[23], line 3
#       1 # working with binary file
#       2 with open("files/minar.jpg", 'r') as f:
# ----> 3     print(f.read())
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
e9\xadd\xdb]X\xcb\xd7\x85\xd4\x04P2C\x92;\xd5\\\x0fR3R\x90\x18d\x1a\x89\xd3\xa8\xef\x8a\xf2\xd9\xd1\xceDT\x9c\x10j\xc4.b99\xdb\xeb\xcdWC\xb5\xb0\xc0`\xfa\xfbS\x8c\x9b\x97\xa6X\x8e\xd5Z\xd8\xe8\xe9r\xe4\xf2\xa6v\xa9\xe9\xd6\x97by\x12\xc8\xed\x8f\x942c\xb1\x15F\x04,\x0ezc\xbf\xb5[\xb6\x90\xc2 ...

# %%
# working with binary file
with open("files/minar.jpg", 'rb') as f:
    original_file = f.read()
    
    with open("files/minar.jpg", "wb") as wf:
        wf.write(original_file)

# %%
# working with other data types
with open('sample.txt','w') as f:
  f.write(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 # working with other data types
#       2 with open('sample.txt','w') as f:
# ----> 3   f.write(5)
#
# TypeError: write() argument must be str, not int

# %%
# working with other data types
with open('files/sample.txt','w') as f:
  f.write("5")

# %%
# working with other data types
with open('files/sample.txt','r') as f:
  data = f.read()
  print(type(data))
  print(data)
# Out:
# <class 'str'>
# 5

# %%
# more complex data
d = {
    'name':'Bappy',
     'age':23,
     'gender':'male'
}

with open('files/sample1.txt','w') as f:
  f.write(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 9
#       2 d = {
#       3     'name':'Bappy',
#       4      'age':23,
#       5      'gender':'male'
#       6 }
#       8 with open('files/sample1.txt','w') as f:
# ----> 9   f.write(d)
#
# TypeError: write() argument must be str, not dict

# %%
# more complex data
d = {
    'name':'Bappy',
     'age':23,
     'gender':'male'
}

with open('files/sample1.txt','w') as f:
  f.write(str(d))

# %%
with open('files/sample1.txt','r') as f:
  s = f.read()
  print(s)
  print(type(s))
# Out:
# {'name': 'Bappy', 'age': 23, 'gender': 'male'}
# <class 'str'>

# %% [markdown]
# ### Serialization and Deserialization
#
# - **Serialization** - process of converting python data types to JSON format
# - **Deserialization** - process of converting JSON to python data types
#
# #### What is JSON?
# The full form of JSON is JavaScript Object Notation.
#
# ![image.png](data:image/png;base64,...)

# %%
import json 

L = [1,2,3,4,5,6]

with open("files/test.json", "w") as f:
    json.dump(L, f)

# %%
import json 

with open("files/test.json", "r") as f:
    data = json.load(f)
    print(data)
    print(type(data))
# Out:
# [1, 2, 3, 4, 5, 6]
# <class 'list'>

# %%
# dict
d = {
    'name':'Bappy',
     'age':23,
     'gender':'male'
}

with open("files/test.json", "w") as f:
    json.dump(d, f, indent=4)

# %%
import json 

with open("files/test.json", "r") as f:
    data = json.load(f)
    print(data)
    print(type(data))
# Out:
# {'name': 'Bappy', 'age': 23, 'gender': 'male'}
# <class 'dict'>

# %%
def main():
    print("Hello Bappy")

# %% [markdown]
# # Pickling in Python

# %% [markdown]
# ### Pickling
# `Pickling` is the process whereby a Python object hierarchy is converted into a byte stream, and `unpickling` is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy.

# %%
def display_info():
    return "Hi my name is Bappy and I am a Programmer"

# %%
d = display_info()

# %%
# pickle dump
import pickle
with open('files/function.pkl','wb') as f:
  pickle.dump(d,f)

# %%
# pickle load
import pickle
with open('files/function.pkl','rb') as f:
  p = pickle.load(f)
  print(p)
# Out:
# {'name': 'Bappy', 'age': 23, 'gender': 'male'}
