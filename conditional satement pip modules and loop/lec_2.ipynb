# %%
print("OK")
# Out:
# OK

# %% [markdown]
# # Conditional statement in pyton

# %% [markdown]
# # modules

# %%
import math
import random
import datetime
import keyword
# import math

# %%
math.sqrt(22002)
print(random.randint(2,50))
print(datetime.datetime.now())
# Out:
# 48
# 2025-11-11 00:26:37.612257

# %%
# !pip install fastapi
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   WARNING: The script fastapi.exe is installed in 'C:\Users\Apurbo\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
