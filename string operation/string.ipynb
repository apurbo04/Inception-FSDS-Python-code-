# %%
a = 32
str(a)
# Out:
# '32'

# %%
text = "it,s a python string"
print(text)
# Out:
# it,s a python string

# %%
mul_text = """Hi! I,m Apurbo.
Student of ICE,PUST."""
print(mul_text)
# Out:
# Hi! I,m Apurbo.
# Student of ICE,PUST.

# %%
print(text[1])
print(text[-3])
# Out:
# t
# i

# %% [markdown]
# ### Python string are immutable

# %%
s ="Apurbo"
# s[2] = "E"
print(s)
# Out:
# Apurbo
